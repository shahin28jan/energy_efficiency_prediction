# %% [markdown]
# The dataset comprises 768 samples. The dataset contains eight attributes (or features, denoted by X1...X8) and two responses (or outcomes, denoted by y1 and y2). The aim is to use the eight features to predict each of the two responses.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("data\energy.xlsx")

# %%
df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %% [markdown]
# Rename all columns

# %%
df.columns = ['relative_compactness', 'surface_area', 'wall_area', 'roof_area', 'overall_height',
                'orientation', 'glazing_area', 'glazing_area_distribution', 'heating_load', 'cooling_load']

# %%
df.head()
# Out:
#    relative_compactness  surface_area  wall_area  roof_area  overall_height  \
# 0                  0.98         514.5      294.0     110.25             7.0
# 1                  0.98         514.5      294.0     110.25             7.0
# 2                  0.98         514.5      294.0     110.25             7.0
# 3                  0.98         514.5      294.0     110.25             7.0
# 4                  0.90         563.5      318.5     122.50             7.0
#
#    orientation  glazing_area  glazing_area_distribution  heating_load  \
# 0            2           0.0                          0         15.55
# 1            3           0.0                          0         15.55
# 2            4           0.0                          0         15.55
# 3            5           0.0                          0         15.55
# 4            2           0.0                          0         20.84
#
#    cooling_load
# 0         21.33
# 1         21.33
# 2         21.33
# 3         21.33
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   relative_compactness       768 non-null    float64
#  1   surface_area               768 non-null    float64
#  2   wall_area                  768 non-null    float64
#  3   roof_area                  768 non-null    float64
#  4   overall_height             768 non-null    float64
#  5   orientation                768 non-null    int64
#  6   glazing_area               768 non-null    float64
#  7   glazing_area_distribution  768 non-null    int64
#  8   heating_load               768 non-null    float64
#  9   cooling_load               768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %% [markdown]
# All attributes and targets are integers or float

# %%
df.isnull().sum()
# Out:
# relative_compactness         0
# surface_area                 0
# wall_area                    0
# roof_area                    0
# overall_height               0
# orientation                  0
# glazing_area                 0
# glazing_area_distribution    0
# heating_load                 0
# cooling_load                 0
# dtype: int64

# %% [markdown]
# There is no null values

# %%
cols = df.columns
for item in cols:
   print(df[item].unique())
# Out:
# [0.98 0.9  0.86 0.82 0.79 0.76 0.74 0.71 0.69 0.66 0.64 0.62]
# [514.5 563.5 588.  612.5 637.  661.5 686.  710.5 735.  759.5 784.  808.5]
# [294.  318.5 343.  416.5 245.  269.5 367.5]
# [110.25 122.5  147.   220.5 ]
# [7.  3.5]
# [2 3 4 5]
# [0.   0.1  0.25 0.4 ]
# [0 1 2 3 4 5]
# [15.55  20.84  21.46  20.71  19.68  19.5   19.95  19.34  18.31  17.05
#  17.41  16.95  15.98  28.52  29.9   29.63  28.75  24.77  23.93   6.07
#   6.05   6.01   6.04   6.37   6.4    6.366  6.85   6.79   6.77   6.81
#   7.18   7.1   10.85  10.54  10.77  10.56   8.6    8.49   8.45   8.5
#  24.58  24.63  24.59  29.03  29.87  29.14  28.09  26.28  26.91  26.37
#  25.27  23.53  24.03  23.54  22.58  35.56  37.12  36.9   35.94  32.96
#  32.12  32.94  32.21  10.36  10.43  10.39  10.71  10.8   10.7   10.75
#  11.11  11.13  11.09  11.16  11.68  11.69  11.7   15.41  15.2   15.42
#  15.21  12.96  12.97  12.93  13.02  24.29  24.31  24.13  24.25  28.88
# ...

# %%
df.describe()
# Out:
#        relative_compactness  surface_area   wall_area   roof_area  \
# count            768.000000    768.000000  768.000000  768.000000
# mean               0.764167    671.708333  318.500000  176.604167
# std                0.105777     88.086116   43.626481   45.165950
# min                0.620000    514.500000  245.000000  110.250000
# 25%                0.682500    606.375000  294.000000  140.875000
# 50%                0.750000    673.750000  318.500000  183.750000
# 75%                0.830000    741.125000  343.000000  220.500000
# max                0.980000    808.500000  416.500000  220.500000
#
#        overall_height  orientation  glazing_area  glazing_area_distribution  \
# count       768.00000   768.000000    768.000000                  768.00000
# mean          5.25000     3.500000      0.234375                    2.81250
# std           1.75114     1.118763      0.133221                    1.55096
# ...

# %%
# boxplot for finding outliers 
plt.figure(figsize=(15, 5))
plt.suptitle('First Chart of bivariate Analysis of all columns with heating_load column', fontsize=20, fontweight='bold', alpha=0.8,y=1)
cols = ['relative_compactness', 'surface_area', 'wall_area', 'roof_area', 'overall_height','orientation', 'glazing_area', 'glazing_area_distribution']
for i in range(0, len(cols)):
    plt.subplot(3, 3, i+1)
    sns.boxplot(data = df, x = df[cols[i]], y = 'heating_load')
    plt.tight_layout()

# %%
# boxplot for finding outliers 
plt.figure(figsize=(15, 5))
plt.suptitle('First Chart of bivariate Analysis of all columns with heating_load column', fontsize=20, fontweight='bold', alpha=0.8,y=1)
cols = ['relative_compactness', 'surface_area', 'wall_area', 'roof_area', 'overall_height','orientation', 'glazing_area', 'glazing_area_distribution']
for i in range(0, len(cols)):
    plt.subplot(3, 3, i+1)
    sns.boxplot(data = df, x = df[cols[i]], y = 'cooling_load')
    plt.tight_layout()

# %% [markdown]
# Looking box plot, we have not to worry about outliers.

# %%
# plot for all columns with heating_load column (target column)
plt.figure(figsize=(15, 5))
plt.suptitle('First Chart of bivariate Analysis of all columns with heating_load column', fontsize=20, fontweight='bold', alpha=0.8,y=1)
cols = ['relative_compactness', 'surface_area', 'wall_area', 'roof_area', 'overall_height','orientation', 'glazing_area', 'glazing_area_distribution']
for i in range(0, len(cols)):
    plt.subplot(3, 3, i+1)
    sns.barplot(data = df, x = df[cols[i]], y = 'heating_load')
    plt.tight_layout()

# %%
# plot for all columns with cooling_load column (target column)
plt.figure(figsize=(15, 5))
plt.suptitle('Chart of bivariate Analysis of all columns with cooling_load column', fontsize=20, fontweight='bold', alpha=0.8,y=1)
cols = ['relative_compactness', 'surface_area', 'wall_area', 'roof_area', 'overall_height','orientation', 'glazing_area', 'glazing_area_distribution']
for i in range(0, len(cols)):
    plt.subplot(3, 3, i+1)
    sns.barplot(data = df, x = df[cols[i]], y = 'cooling_load')
    plt.tight_layout()

# %% [markdown]
# attribute orientation has no significent effect on heating_load.

# %% [markdown]
# For target column cooling_load, feature orientation has no significent effect. In both target columns it is not going to effect . i can drop this feature.
# In both target data their value is low when glazing_area_distribution is zero otherwise all values are same.

# %%
##correlation
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)
